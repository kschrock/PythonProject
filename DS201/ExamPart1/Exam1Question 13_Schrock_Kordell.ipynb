# %%
import pandas as pd
import matplotlib.pylab as plt
import numpy as np
import seaborn as sns
import statistics

# %%
array = [12, 3, 12, 4, 18, 17, 16, 13, 5, 4, 5, 7, 16, 15]
df = pd.DataFrame()
df['array'] = array
hist = df.boxplot(column='array',rot =45, figsize = (10,7), fontsize = 10, grid = False)
plt.show()

# %%
x = statistics.mean(array)
print(x)
# Out:
# 10.5

# %%
y = statistics.median(array)
print(y)
# Out:
# 12.0
